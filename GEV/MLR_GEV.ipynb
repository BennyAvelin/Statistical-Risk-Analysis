# %%
install.packages("extRemes")

# %%
library(extRemes)
# Out:
# Loading required package: Lmoments
#
# Loading required package: distillery
#
#
# Attaching package: 'extRemes'
#
#
# The following objects are masked from 'package:stats':
#
#     qqnorm, qqplot

# %%
dat = revd(1000,loc=1,scale=1,shape=1/10)

# %%
hist(dat,breaks=100)
# Out:
# Plot with title "Histogram of dat"

# %%
fevd(dat)
# Out:
# fevd(x = dat)
#
# [1] "Estimation Method used: MLE"
#
#
#  Negative Log-Likelihood Value:  1595.668
#
#
#  Estimated parameters:
#  location     scale     shape
# 0.9371532 0.9523854 0.1159914
#
#  Standard Error Estimates:
#   location      scale      shape
# 0.03399336 0.02588557 0.02431793
#
#  Estimated parameter covariance matrix.
#               location         scale         shape
# location  0.0011555483  4.358676e-04 -2.669236e-04
# scale     0.0004358676  6.700629e-04 -9.750889e-05
# shape    -0.0002669236 -9.750889e-05  5.913620e-04
#
#  AIC = 3197.335
#
#  BIC = 3212.058
